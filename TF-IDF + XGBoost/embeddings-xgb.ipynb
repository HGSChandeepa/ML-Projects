# %%
from sentence_transformers import SentenceTransformer
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# Sample dataset
texts = ["I love machine learning", "Python is amazing", "I hate bugs", "Debugging is fun", "I enjoy AI and NLP"]
labels = [1, 1, 0, 0, 1]

# %%
# Multilingual embeddings
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(texts)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(embeddings, labels, test_size=0.2, random_state=42)

# %%
import os
os.environ["NUMPY_EXPERIMENTAL_ARRAY_FUNCTION"] = "0"

# %%
import numpy as np

# Convert to numpy arrays explicitly
X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

# Then fit
clf = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 9
#       7 # Then fit
#       8 clf = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
# ----> 9 clf.fit(X_train, y_train)
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\sklearn.py:1231, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1228     label_transform = lambda x: x
#    1230 model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
# -> 1231 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1232     missing=self.missing,
#    1233     X=X,
#    1234     y=y,
#    1235     group=None,
#    1236     qid=None,
#    1237     sample_weight=sample_weight,
#    1238     base_margin=base_margin,
#    1239     feature_weights=feature_weights,
#    1240     eval_set=eval_set,
#    1241     sample_weight_eval_set=sample_weight_eval_set,
#    1242     base_margin_eval_set=base_margin_eval_set,
#    1243     eval_group=None,
#    1244     eval_qid=None,
#    1245     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#    1246     enable_categorical=self.enable_categorical,
#    1247     label_transform=label_transform,
#    1248 )
#    1250 self._Booster = train(
#    1251     params,
#    1252     train_dmatrix,
#    (...)   1261     callbacks=callbacks,
#    1262 )
#    1264 if not callable(self.objective):
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\sklearn.py:286, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, label_transform)
#     265 def _wrap_evaluation_matrices(
#     266     missing: float,
#     267     X: Any,
#    (...)    281     label_transform: Callable = lambda x: x,
#     282 ) -> Tuple[Any, Optional[List[Tuple[Any, str]]]]:
#     283     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the way.
#     284
#     285     """
# --> 286     train_dmatrix = create_dmatrix(
#     287         data=X,
#     288         label=label_transform(y),
#     289         group=group,
#     290         qid=qid,
#     291         weight=sample_weight,
#     292         base_margin=base_margin,
#     293         feature_weights=feature_weights,
#     294         missing=missing,
#     295         enable_categorical=enable_categorical,
#     296     )
#     298     n_validation = 0 if eval_set is None else len(eval_set)
#     300     def validate_or_none(meta: Optional[List], name: str) -> List:
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\sklearn.py:1245, in XGBClassifier.fit.<locals>.<lambda>(**kwargs)
#    1228     label_transform = lambda x: x
#    1230 model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
#    1231 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1232     missing=self.missing,
#    1233     X=X,
#    1234     y=y,
#    1235     group=None,
#    1236     qid=None,
#    1237     sample_weight=sample_weight,
#    1238     base_margin=base_margin,
#    1239     feature_weights=feature_weights,
#    1240     eval_set=eval_set,
#    1241     sample_weight_eval_set=sample_weight_eval_set,
#    1242     base_margin_eval_set=base_margin_eval_set,
#    1243     eval_group=None,
#    1244     eval_qid=None,
# -> 1245     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#    1246     enable_categorical=self.enable_categorical,
#    1247     label_transform=label_transform,
#    1248 )
#    1250 self._Booster = train(
#    1251     params,
#    1252     train_dmatrix,
#    (...)   1261     callbacks=callbacks,
#    1262 )
#    1264 if not callable(self.objective):
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\core.py:627, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     624 assert handle is not None
#     625 self.handle = handle
# --> 627 self.set_info(
#     628     label=label,
#     629     weight=weight,
#     630     base_margin=base_margin,
#     631     group=group,
#     632     qid=qid,
#     633     label_lower_bound=label_lower_bound,
#     634     label_upper_bound=label_upper_bound,
#     635     feature_weights=feature_weights,
#     636 )
#     638 if feature_names is not None:
#     639     self.feature_names = feature_names
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\core.py:694, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#     691 from .data import dispatch_meta_backend
#     693 if label is not None:
# --> 694     self.set_label(label)
#     695 if weight is not None:
#     696     self.set_weight(weight)
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\core.py:825, in DMatrix.set_label(self, label)
#     817 """Set label of dmatrix
#     818
#     819 Parameters
#    (...)    822     The label information to be set into DMatrix
#     823 """
#     824 from .data import dispatch_meta_backend
# --> 825 dispatch_meta_backend(self, label, 'label', 'float')
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\data.py:907, in dispatch_meta_backend(matrix, data, name, dtype)
#     905 def _arrow_feature_info(data: DataType) -> Tuple[List[str], List]:
#     906     if TYPE_CHECKING:
# --> 907         import pyarrow as pa
#     908     else:
#     909         pa = import_pyarrow()
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\data.py:833, in _meta_from_numpy(data, field, dtype, handle)
#     832 def _meta_from_numpy(data, field, dtype, handle):
# --> 833     data = _maybe_np_slice(data, dtype)
#     834     interface = data.__array_interface__
#     835     assert interface.get('mask', None) is None, 'Masked array is not supported'
#
# File d:\Self study\Deep Learning\projects\.venv\Lib\site-packages\xgboost\data.py:150, in _maybe_np_slice(data, dtype)
#     148         data = np.array(data, copy=True, dtype=dtype)
#     149     else:
# --> 150         data = np.array(data, copy=False, dtype=dtype)
#     151 except AttributeError:
#     152     data = np.array(data, copy=False, dtype=dtype)
#
# ValueError: Unable to avoid copy while creating an array as requested.
# If using `np.array(obj, copy=False)` replace it with `np.asarray(obj)` to allow a copy when needed (no behavior change in NumPy 1.x).
# For more details, see https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword.

# %%
# Predictions
y_pred = clf.predict(X_test)

# Evaluation
print(classification_report(y_test, y_pred))
